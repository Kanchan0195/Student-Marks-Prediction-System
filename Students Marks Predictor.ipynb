# %%
#import essential libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 #import essential libraries
# ----> 2 import numpy as np
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#import dataset
df=pd.read_csv("student_info.csv")
df.head()
# Out:
#    study_hours  student_marks
# 0         6.83          78.50
# 1         6.56          76.74
# 2          NaN          78.68
# 3         5.67          71.82
# 4         8.67          84.19

# %%
#data visualisation
plt.scatter(x=df.study_hours, y=df.student_marks)
plt.title("Student Marks Predictor")
plt.xlabel("Study Hours")
plt.ylabel("Student Marks")
plt.show()

# %%
#check missing values 
df.isnull().sum()
# Out:
# study_hours      5
# student_marks    0
# dtype: int64

# %%
#handle missing values
df=df.fillna(df.mean())

# %%
df.isnull().sum()
# Out:
# study_hours      0
# student_marks    0
# dtype: int64

# %%
#seprate dataset into independent and dependent data variables
x=df.drop("stu")

# %%
# separate dataset into independent and dependant data variables.
x=df.drop("student_marks",axis=1)
y=df.drop("study_hours",axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # separate dataset into independent and dependant data variables.
# ----> 2 x=df.drop("student_marks",axis=1)
#       3 y=df.drop("study_hours",axis=1)
#
# NameError: name 'df' is not defined

# %%
x.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 x.head()
#
# NameError: name 'x' is not defined
